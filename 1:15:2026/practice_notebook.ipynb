# %% [markdown]
# this is my first vs code

# %% [markdown]
# there are different ways to change fonts
#
# <font size = "4">
#
# Font size 4
#
# # Big text
#
# ## slightly smaller
#
# ###### really small

# %%
print("Hello World!")
# Out:
# Hello World!
